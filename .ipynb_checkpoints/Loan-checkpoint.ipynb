# %%
import pandas  as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_classification, make_blobs
from sklearn.preprocessing import PowerTransformer,FunctionTransformer
from sklearn.model_selection import train_test_split

from sklearn.compose import ColumnTransformer

from sklearn.metrics import accuracy_score, precision_score,recall_score,roc_auc_score, confusion_matrix

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.shape
# Out:
# (45000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 4.8+ MB

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %%
# plt.figure(figsize = (15,6))
# sns.scatterplot(data = df, x= 'person_age',y = 'person_income',hue = 'loan_status')
# plt.xlim(20,80)
# # plt.ylim(1,5)

# %% [markdown]
# # Insights for numerical columns
# 1. Which feature are governing that the loan will be approved or rejected
#    -  if previous defaulters chances are the loan will be rejected.
#    -  credit score could be the feature which is deciding the rejection or approval of the loan, if more, chances are loan is apporved
#    -  cb_person_cred_hist_length, if its more, chances are the loan is approved
#    - loan intent, plays a role in rejection and approval
#    - person_home_ownership, mostly rejecting if its mortgage
#    - loan_percent_income, if low, its rejecting the loan, very important column
#    - previous_loan_defaults_on_file, if yes, THEN 100% loan is not given. very strong
#    - Cant drop rows just like that, the data is imbalanced with only 22% of the minority class

# %% [markdown]
# # actions on the numerical columns
# - Yeo johnson tranformation on the age, loan amount

# %%
df[df['loan_status'] ==0].count()
# Out:
# person_age                        35000
# person_gender                     35000
# person_education                  35000
# person_income                     35000
# person_emp_exp                    35000
# person_home_ownership             35000
# loan_amnt                         35000
# loan_intent                       35000
# loan_int_rate                     35000
# loan_percent_income               35000
# cb_person_cred_hist_length        35000
# credit_score                      35000
# previous_loan_defaults_on_file    35000
# loan_status                       35000
# dtype: int64

# %%
10000/45000*100
# Out:
# 22.22222222222222

# %% [markdown]
# ## there is imbalance in the output classes, we will use smote to oversample the minority class. but before that analysis of the columns

# %% [markdown]
# # Univaraite analysis of the numerical columns

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %%
temp =df.copy()

# %%
fig , axes = plt.subplots(3,3,figsize = (20,20))
sns.kdeplot(data = df, x='person_age',ax=axes[0][0])
sns.boxplot(data = df, x='person_age',ax=axes[0][1])
sns.kdeplot(data = df, x='loan_amnt',ax=axes[0][2])
sns.boxplot(data = df, x='loan_amnt',ax=axes[1][0])
sns.kdeplot(data = df, x='cb_person_cred_hist_length',ax=axes[1][1])
sns.kdeplot(data = df, x='loan_int_rate',ax=axes[1][2])
sns.kdeplot(data = df, x='credit_score',ax=axes[2][0])
sns.boxplot(data = df, x = 'loan_percent_income',ax=axes[2][1])
# Out:
# <Axes: xlabel='person_age_yeo', ylabel='Density'>

# %%
# dropping the rows having person age >70 as there are zero entires for loan status == 1, 
# and hence minority class is not dropped and we have dropped some outliers too

# %%
df = df[df['person_age']<70]

# %%
df[df['cb_person_cred_hist_length']>20][df[df['cb_person_cred_hist_length']>20]['loan_status']==1]
# Out:
#        person_age person_gender person_education  person_income  \
# 32299        65.0        female        Associate        92502.0
# 32307        54.0          male      High School        65135.0
# 32309        66.0        female      High School        73126.0
# 32310        57.0          male        Associate        18747.0
# 32312        51.0          male        Associate       184501.0
# ...           ...           ...              ...            ...
# 43843        49.0        female           Master        86529.0
# 43852        47.0          male        Associate        44111.0
# 44220        60.0          male         Bachelor        55787.0
# 44542        48.0        female           Master        65958.0
# 44627        47.0          male        Doctorate        70131.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 32299              43                  RENT    35000.0          EDUCATION
# 32307              34                  RENT    29850.0    HOMEIMPROVEMENT
# 32309              42                  RENT    27050.0            MEDICAL
# 32310              34              MORTGAGE     3000.0  DEBTCONSOLIDATION
# 32312              27                  RENT    25000.0           PERSONAL
# ...               ...                   ...        ...                ...
# 43843              25                  RENT     7000.0          EDUCATION
# 43852              23                  RENT    11160.0            MEDICAL
# 44220              37                  RENT    20000.0  DEBTCONSOLIDATION
# 44542              24                  RENT     1169.0  DEBTCONSOLIDATION
# 44627              22                  RENT     1500.0            MEDICAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 32299          10.99                 0.38                        27.0
# 32307          11.01                 0.46                        28.0
# 32309          11.01                 0.37                        28.0
# 32310          12.68                 0.16                        23.0
# 32312          15.58                 0.14                        23.0
# ...              ...                  ...                         ...
# 43843          16.71                 0.08                        26.0
# 43852          11.86                 0.25                        24.0
# 44220          10.00                 0.36                        22.0
# 44542          14.14                 0.02                        21.0
# 44627          16.17                 0.02                        22.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 32299           735                             No            1
# 32307           637                             No            1
# 32309           719                             No            1
# 32310           676                             No            1
# 32312           707                             No            1
# ...             ...                            ...          ...
# 43843           745                             No            1
# 43852           576                             No            1
# 44220           710                             No            1
# 44542           704                             No            1
# 44627           735                             No            1
#
# [63 rows x 14 columns]

# %%
temp = df[df['person_age']>40]

# %%
# df[df['person_age']>40][df[df['person_age']>40]['loan_status']==0]

# %%
temp
# Out:
#        person_age person_gender person_education  person_income  \
# 29121        50.0          male      High School      1081082.0
# 29124        45.0          male           Master        96924.0
# 29127        44.0          male      High School       703125.0
# 29131        43.0        female           Master       600812.0
# 29133        41.0          male        Associate       577228.0
# ...           ...           ...              ...            ...
# 44916        42.0        female      High School       100310.0
# 44923        47.0          male        Associate        46637.0
# 44947        42.0          male        Doctorate       705960.0
# 44972        43.0          male        Associate       184295.0
# 44977        43.0          male        Associate        22639.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29121              28              MORTGAGE    30000.0  DEBTCONSOLIDATION
# 29124              25                  RENT    35000.0            MEDICAL
# 29127              24              MORTGAGE    20000.0            MEDICAL
# 29131              22              MORTGAGE    25000.0            VENTURE
# 29133              17              MORTGAGE    16000.0  DEBTCONSOLIDATION
# ...               ...                   ...        ...                ...
# 44916              21                 OTHER    12000.0          EDUCATION
# 44923              24                  RENT    13000.0            MEDICAL
# 44947              21              MORTGAGE    20686.0           PERSONAL
# 44972              20              MORTGAGE    25000.0          EDUCATION
# 44977              21                  RENT     1111.0           PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 29121          12.69                 0.03                        15.0
# 29124          11.01                 0.36                        13.0
# 29127          11.01                 0.03                        16.0
# 29131          12.61                 0.04                        14.0
# 29133           7.90                 0.03                        17.0
# ...              ...                  ...                         ...
# 44916          16.16                 0.12                        14.0
# 44923          11.70                 0.28                        18.0
# 44947          10.74                 0.03                        16.0
# 44972          20.00                 0.14                        15.0
# 44977          14.78                 0.05                        14.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 29121           643                             No            0
# 29124           566                             No            1
# 29127           563                             No            1
# 29131           685                             No            0
# 29133           660                             No            0
# ...             ...                            ...          ...
# 44916           665                             No            1
# 44923           705                             No            1
# 44947           689                             No            1
# 44972           720                             No            1
# 44977           594                             No            1
#
# [1817 rows x 14 columns]

# %%
sns.boxplot(data = temp, x = 'loan_amnt')
# Out:
# <Axes: xlabel='loan_amnt'>

# %%
rejected = temp[temp['loan_amnt']>26000][temp[temp['loan_amnt']>26000]['loan_status']==0]

# %%
# sns.boxplot(data = temp, x = 'person_income')

# %%
approved = temp[temp['loan_amnt']>26000][temp[temp['loan_amnt']>26000]['loan_status']==1]

# %%
rejected['person_income'].mean()
# Out:
# 322368.7894736842

# %%
approved['person_income'].mean()
# Out:
# 98833.55555555556

# %%
approved
# Out:
#        person_age person_gender person_education  person_income  \
# 29124        45.0          male           Master        96924.0
# 29140        44.0          male        Associate        82056.0
# 29141        43.0        female      High School        89491.0
# 31232        42.0        female         Bachelor        78231.0
# 31630        46.0          male         Bachelor       125725.0
# 31865        44.0        female         Bachelor       169912.0
# 32183        46.0        female        Associate       106941.0
# 32265        42.0        female         Bachelor        78378.0
# 32299        65.0        female        Associate        92502.0
# 32301        53.0          male      High School       103338.0
# 32302        58.0          male         Bachelor       130995.0
# 32307        54.0          male      High School        65135.0
# 32309        66.0        female      High School        73126.0
# 32578        65.0          male      High School        91852.0
# 43787        42.0        female        Associate        96969.0
# 43814        45.0          male        Associate        96916.0
# 43838        61.0          male        Associate        73448.0
# 44209        45.0        female      High School       127065.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29124              25                  RENT    35000.0            MEDICAL
# 29140              20                  RENT    32400.0    HOMEIMPROVEMENT
# 29141              19                  RENT    30600.0  DEBTCONSOLIDATION
# 31232              20              MORTGAGE    30000.0            MEDICAL
# 31630              25              MORTGAGE    30000.0          EDUCATION
# 31865              19              MORTGAGE    35000.0            MEDICAL
# 32183              25              MORTGAGE    30000.0            MEDICAL
# 32265              19              MORTGAGE    30000.0            MEDICAL
# 32299              43                  RENT    35000.0          EDUCATION
# 32301              30                  RENT    35000.0           PERSONAL
# 32302              33                  RENT    35000.0           PERSONAL
# 32307              34                  RENT    29850.0    HOMEIMPROVEMENT
# 32309              42                  RENT    27050.0            MEDICAL
# 32578              45                  RENT    35000.0    HOMEIMPROVEMENT
# 43787              22                  RENT    35000.0           PERSONAL
# 43814              21                  RENT    35000.0           PERSONAL
# 43838              35                  RENT    26550.0          EDUCATION
# 44209              26              MORTGAGE    30000.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 29124          11.01                 0.36                        13.0
# 29140          11.01                 0.39                        13.0
# 29141          18.79                 0.34                        17.0
# 31232          19.03                 0.38                        17.0
# 31630          18.39                 0.24                        15.0
# 31865          16.49                 0.21                        15.0
# 32183          18.39                 0.28                        16.0
# 32265          19.03                 0.38                        14.0
# 32299          10.99                 0.38                        27.0
# 32301          15.65                 0.34                        19.0
# 32302          14.91                 0.27                        19.0
# 32307          11.01                 0.46                        28.0
# 32309          11.01                 0.37                        28.0
# 32578          10.99                 0.38                        28.0
# 43787          11.43                 0.36                        15.0
# 43814          11.08                 0.36                        14.0
# 43838          10.76                 0.36                        26.0
# 44209          17.91                 0.24                        14.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 29124           566                             No            1
# 29140           638                             No            1
# 29141           648                             No            1
# 31232           640                             No            1
# 31630           704                             No            1
# 31865           634                             No            1
# 32183           744                             No            1
# 32265           687                             No            1
# 32299           735                             No            1
# 32301           649                             No            1
# 32302           740                             No            1
# 32307           637                             No            1
# 32309           719                             No            1
# 32578           686                             No            1
# 43787           583                             No            1
# 43814           650                             No            1
# 43838           733                             No            1
# 44209           690                             No            1

# %%
rejected
# Out:
#        person_age person_gender person_education  person_income  \
# 29121        50.0          male      High School      1081082.0
# 29137        43.0        female           Master       480854.0
# 29169        41.0        female      High School       270601.0
# 30148        46.0          male           Master        58618.0
# 31234        42.0          male      High School        99779.0
# 31584        41.0        female      High School       132836.0
# 31647        41.0          male        Doctorate       142960.0
# 31702        42.0          male         Bachelor       151000.0
# 31909        41.0          male        Associate       458696.0
# 31952        41.0          male        Associate       132989.0
# 32068        42.0          male        Associate       151217.0
# 32075        43.0          male         Bachelor       480837.0
# 32124        41.0          male      High School       458692.0
# 32305        66.0          male      High School       360994.0
# 32306        61.0          male      High School       193233.0
# 32484        66.0          male        Associate        99448.0
# 32524        51.0          male        Associate       144986.0
# 36005        48.0          male        Associate       145233.0
# 40161        46.0          male      High School      1080952.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29121              28              MORTGAGE    30000.0  DEBTCONSOLIDATION
# 29137              20              MORTGAGE    28000.0            VENTURE
# 29169              16              MORTGAGE    35000.0    HOMEIMPROVEMENT
# 30148              24                   OWN    27175.0            VENTURE
# 31234              22              MORTGAGE    26800.0    HOMEIMPROVEMENT
# 31584              20              MORTGAGE    30000.0            VENTURE
# 31647              18              MORTGAGE    28000.0            MEDICAL
# 31702              20              MORTGAGE    35000.0            MEDICAL
# 31909              17              MORTGAGE    35000.0            MEDICAL
# 31952              19              MORTGAGE    30000.0            VENTURE
# 32068              22              MORTGAGE    35000.0            VENTURE
# 32075              21              MORTGAGE    28000.0    HOMEIMPROVEMENT
# 32124              18              MORTGAGE    35000.0           PERSONAL
# 32305              44              MORTGAGE    28000.0           PERSONAL
# 32306              43                  RENT    30000.0           PERSONAL
# 32484              43              MORTGAGE    28000.0           PERSONAL
# 32524              27              MORTGAGE    30000.0           PERSONAL
# 36005              28              MORTGAGE    29700.0            MEDICAL
# 40161              27              MORTGAGE    28389.0           PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 29121          12.69                 0.03                        15.0
# 29137           9.91                 0.06                        11.0
# 29169          15.62                 0.13                        14.0
# 30148           8.49                 0.46                        13.0
# 31234          11.01                 0.27                        15.0
# 31584           9.91                 0.23                        11.0
# 31647          11.71                 0.20                        13.0
# 31702           7.90                 0.23                        12.0
# 31909          13.49                 0.08                        14.0
# 31952           9.91                 0.23                        17.0
# 32068           7.90                 0.23                        17.0
# 32075           9.91                 0.06                        11.0
# 32124          13.49                 0.08                        16.0
# 32305           6.62                 0.08                        23.0
# 32306          11.01                 0.16                        27.0
# 32484           7.90                 0.28                        20.0
# 32524           7.90                 0.21                        22.0
# 36005           9.42                 0.20                        20.0
# 40161          12.75                 0.03                        15.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 29121           643                             No            0
# 29137           619                             No            0
# 29169           548                            Yes            0
# 30148           659                            Yes            0
# 31234           655                             No            0
# 31584           624                            Yes            0
# 31647           707                             No            0
# 31702           742                             No            0
# 31909           558                            Yes            0
# 31952           687                             No            0
# 32068           675                             No            0
# 32075           702                            Yes            0
# 32124           676                            Yes            0
# 32305           731                             No            0
# 32306           734                             No            0
# 32484           711                             No            0
# 32524           640                            Yes            0
# 36005           672                             No            0
# 40161           639                            Yes            0

# %%
sns.boxplot(data = df, x = 'loan_percent_income')
# Out:
# <Axes: xlabel='loan_percent_income'>

# %%
df[df['loan_percent_income']>0.5][df[df['loan_percent_income']>0.5]['loan_status']==1]
# Out:
#        person_age person_gender person_education  person_income  \
# 4            24.0          male           Master        66135.0
# 36           22.0        female         Bachelor        58868.0
# 460          24.0          male        Associate        22684.0
# 493          23.0          male         Bachelor        43042.0
# 535          22.0          male      High School        38473.0
# 571          21.0        female        Associate        24468.0
# 577          26.0          male      High School        32325.0
# 583          23.0        female      High School        39416.0
# 962          23.0          male        Associate        33227.0
# 1348         22.0          male      High School        32114.0
# 5590         22.0        female         Bachelor        47716.0
# 6758         22.0          male           Master        13294.0
# 7220         24.0          male        Associate        55979.0
# 10007        21.0          male           Master        16412.0
# 14407        22.0        female         Bachelor        29643.0
# 15877        26.0        female        Associate        37071.0
# 15921        23.0          male      High School        36911.0
# 17290        23.0          male         Bachelor        36697.0
# 17938        27.0          male           Master        15675.0
# 17956        34.0          male        Associate        48619.0
# 18082        30.0          male         Bachelor        18002.0
# 18203        30.0          male         Bachelor        39324.0
# 18204        30.0          male         Bachelor        44381.0
# 18316        31.0        female      High School        40149.0
# 18322        31.0          male        Associate        37391.0
# 18672        28.0          male        Associate        29696.0
# 23727        32.0        female        Associate        15340.0
# 27878        33.0          male         Bachelor        13376.0
# 28648        34.0          male        Associate        49030.0
# 28724        31.0          male      High School        37662.0
# 42327        30.0          male        Associate        37481.0
# 42505        27.0          male         Bachelor        15257.0
# 42711        25.0        female      High School        23386.0
# 42788        23.0        female      High School        38344.0
# 42984        23.0          male        Associate        23561.0
# 43649        24.0          male        Associate        56526.0
# 44708        28.0        female      High School        36850.0
# 44903        25.0          male        Associate        43219.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 4                   1                  RENT    35000.0            MEDICAL
# 36                  0                  RENT    30000.0          EDUCATION
# 460                 0                   OWN    13000.0           PERSONAL
# 493                 1                  RENT    22250.0  DEBTCONSOLIDATION
# 535                 0                  RENT    21250.0  DEBTCONSOLIDATION
# 571                 0              MORTGAGE    15000.0          EDUCATION
# 577                 4                  RENT    20050.0          EDUCATION
# 583                 0                  RENT    20000.0  DEBTCONSOLIDATION
# 962                 0                  RENT    18000.0            VENTURE
# 1348                2              MORTGAGE    17000.0            VENTURE
# 5590                2                   OWN    25000.0          EDUCATION
# 6758                0                  RENT     7000.0    HOMEIMPROVEMENT
# 7220                6              MORTGAGE    29100.0           PERSONAL
# 10007               0                  RENT     9250.0  DEBTCONSOLIDATION
# 14407               0                  RENT    15000.0           PERSONAL
# 15877               7                  RENT    19075.0  DEBTCONSOLIDATION
# 15921               2                  RENT    19750.0            VENTURE
# 17290               1                  RENT    19750.0            VENTURE
# 17938               4                   OWN     8125.0          EDUCATION
# 17956              12                  RENT    25000.0            MEDICAL
# 18082               7                   OWN     9250.0    HOMEIMPROVEMENT
# 18203               8                  RENT    24250.0           PERSONAL
# 18204               7                  RENT    24250.0  DEBTCONSOLIDATION
# 18316               4                  RENT    20500.0  DEBTCONSOLIDATION
# 18322               8                  RENT    20200.0           PERSONAL
# 18672               8                  RENT    16750.0            MEDICAL
# 23727              10                  RENT     9325.0            MEDICAL
# 27878               8                   OWN     7200.0            VENTURE
# 28648              14                  RENT    25000.0          EDUCATION
# 28724              10                  RENT    20200.0           PERSONAL
# 42327               8                  RENT    20134.0            VENTURE
# 42505               4                  RENT     8118.0          EDUCATION
# 42711               3                  RENT    12589.0            VENTURE
# 42788               0                  RENT    21199.0  DEBTCONSOLIDATION
# 42984               1                   OWN    13897.0           PERSONAL
# 43649               2                  RENT    29227.0          EDUCATION
# 44708               6                  RENT    19425.0            VENTURE
# 44903               1                  RENT    22807.0            MEDICAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 4              14.27                 0.53                         4.0
# 36             18.39                 0.51                         2.0
# 460             7.88                 0.57                         3.0
# 493            12.69                 0.52                         3.0
# 535            12.42                 0.55                         3.0
# 571             9.64                 0.61                         2.0
# 577             9.76                 0.62                         2.0
# 583            12.61                 0.51                         4.0
# 962            11.54                 0.54                         4.0
# 1348           12.84                 0.53                         4.0
# 5590           16.08                 0.52                         3.0
# 6758           12.21                 0.53                         2.0
# 7220           12.99                 0.52                         2.0
# 10007          12.53                 0.56                         3.0
# 14407          12.73                 0.51                         4.0
# 15877           7.49                 0.51                         3.0
# 15921          11.14                 0.54                         4.0
# 17290          11.14                 0.54                         4.0
# 17938          14.42                 0.52                         5.0
# 17956          10.25                 0.51                         8.0
# 18082          14.96                 0.51                        10.0
# 18203          11.12                 0.62                         5.0
# 18204          12.61                 0.55                         7.0
# 18316          11.03                 0.51                         6.0
# 18322          14.74                 0.54                         5.0
# 18672          14.96                 0.56                        10.0
# 23727           8.38                 0.61                         6.0
# 27878           6.03                 0.54                         8.0
# 28648          10.25                 0.51                         5.0
# 28724          14.74                 0.54                         8.0
# 42327          14.21                 0.54                         5.0
# 42505          14.34                 0.53                         5.0
# 42711           7.96                 0.54                         4.0
# 42788          12.53                 0.55                         4.0
# 42984           8.67                 0.59                         3.0
# 43649          13.75                 0.52                         2.0
# 44708           9.74                 0.53                         4.0
# 44903          12.67                 0.53                         5.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 4               586                             No            1
# 36              606                             No            1
# 460             640                             No            1
# 493             678                             No            1
# 535             599                             No            1
# 571             548                             No            1
# 577             652                             No            1
# 583             593                             No            1
# 962             679                             No            1
# 1348            634                             No            1
# 5590            685                             No            1
# 6758            652                             No            1
# 7220            601                             No            1
# 10007           707                             No            1
# 14407           689                             No            1
# 15877           588                             No            1
# 15921           618                             No            1
# 17290           660                             No            1
# 17938           505                             No            1
# 17956           638                             No            1
# 18082           683                             No            1
# 18203           671                             No            1
# 18204           655                             No            1
# 18316           614                             No            1
# 18322           589                             No            1
# 18672           677                             No            1
# 23727           673                             No            1
# 27878           715                             No            1
# 28648           611                             No            1
# 28724           604                             No            1
# 42327           613                             No            1
# 42505           674                             No            1
# 42711           494                             No            1
# 42788           653                             No            1
# 42984           671                             No            1
# 43649           642                             No            1
# 44708           607                             No            1
# 44903           668                             No            1

# %%
df[df['credit_score']>750].groupby('loan_status').count()
# Out:
#              person_age  person_gender  person_education  person_income  \
# loan_status
# 0                    18             18                18             18
# 1                     7              7                 7              7
#
#              person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# loan_status
# 0                        18                     18         18           18
# 1                         7                      7          7            7
#
#              loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# loan_status
# 0                       18                   18                          18
# 1                        7                    7                           7
#
#              credit_score  previous_loan_defaults_on_file
# loan_status
# 0                      18                              18
# 1                       7                               7

# %%
df[df['credit_score']>750]
# Out:
#        person_age person_gender person_education  person_income  \
# 14923        23.0          male         Bachelor       130529.0
# 25259        29.0          male        Doctorate        57579.0
# 29271        41.0          male        Doctorate        72894.0
# 29488        37.0          male           Master        35648.0
# 30129        43.0          male        Doctorate        58727.0
# 30697        49.0        female           Master        75149.0
# 31121        48.0          male           Master        66910.0
# 31373        46.0        female           Master       108819.0
# 32278        46.0        female        Doctorate        68149.0
# 32300        51.0        female        Doctorate       802050.0
# 32357        53.0          male        Doctorate        41702.0
# 32364        69.0          male         Bachelor        45454.0
# 32377        64.0          male         Bachelor        56272.0
# 32378        69.0          male           Master        97535.0
# 32419        61.0        female        Doctorate        64516.0
# 32449        53.0        female           Master       102846.0
# 32544        58.0          male           Master       936965.0
# 32568        60.0          male           Master        59707.0
# 33723        53.0          male        Doctorate       105115.0
# 34166        50.0          male         Bachelor        82442.0
# 39296        40.0          male        Doctorate       115106.0
# 43613        28.0          male           Master        30926.0
# 44050        38.0          male         Bachelor        63903.0
# 44658        44.0        female           Master        21702.0
# 44705        52.0        female         Bachelor        59758.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 14923               2              MORTGAGE    10000.0  DEBTCONSOLIDATION
# 25259               9                  RENT    12000.0            VENTURE
# 29271              17                  RENT    23800.0    HOMEIMPROVEMENT
# 29488              18              MORTGAGE     7750.0  DEBTCONSOLIDATION
# 30129              23                  RENT     5500.0            MEDICAL
# 30697              27              MORTGAGE    12000.0           PERSONAL
# 31121              24                  RENT    10200.0            MEDICAL
# 31373              24              MORTGAGE    20000.0  DEBTCONSOLIDATION
# 32278              23              MORTGAGE     6000.0            MEDICAL
# 32300              26              MORTGAGE    10000.0           PERSONAL
# 32357              29              MORTGAGE    10000.0            MEDICAL
# 32364              49                  RENT    10750.0            MEDICAL
# 32377              44                  RENT     4800.0           PERSONAL
# 32378              48                  RENT     4800.0            MEDICAL
# 32419              39              MORTGAGE     7000.0           PERSONAL
# 32449              30                  RENT     8000.0            MEDICAL
# 32544              36              MORTGAGE     4500.0           PERSONAL
# 32568              38                   OWN    12000.0           PERSONAL
# 33723              31                  RENT    15000.0    HOMEIMPROVEMENT
# 34166              27              MORTGAGE     8000.0            VENTURE
# 39296              18              MORTGAGE    21548.0    HOMEIMPROVEMENT
# 43613               4                  RENT    10934.0          EDUCATION
# 44050              16                  RENT     6532.0    HOMEIMPROVEMENT
# 44658              19                  RENT     1500.0           PERSONAL
# 44705              26                  RENT     7399.0            MEDICAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 14923          11.01                 0.08                         2.0
# 25259           7.29                 0.21                         8.0
# 29271           6.91                 0.33                        15.0
# 29488          11.01                 0.22                        16.0
# 30129          12.61                 0.09                        17.0
# 30697          12.21                 0.16                        12.0
# 31121          13.92                 0.15                        16.0
# 31373           6.91                 0.18                        16.0
# 32278          11.01                 0.09                        13.0
# 32300          13.98                 0.01                        22.0
# 32357          10.39                 0.24                        30.0
# 32364          14.59                 0.24                        27.0
# 32377          11.09                 0.09                        24.0
# 32378          14.79                 0.05                        22.0
# 32419           7.49                 0.11                        23.0
# 32449           7.74                 0.08                        28.0
# 32544           6.91                 0.00                        20.0
# 32568          13.79                 0.20                        21.0
# 33723           8.50                 0.14                        21.0
# 34166          10.11                 0.10                        23.0
# 39296          13.98                 0.19                        12.0
# 43613          10.49                 0.35                         9.0
# 44050          14.14                 0.10                        16.0
# 44658          11.21                 0.07                        12.0
# 44705          13.04                 0.12                        20.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 14923           751                             No            1
# 25259           762                             No            0
# 29271           755                             No            1
# 29488           759                             No            0
# 30129           756                             No            0
# 30697           753                             No            0
# 31121           755                            Yes            0
# 31373           764                             No            0
# 32278           759                            Yes            0
# 32300           760                             No            0
# 32357           755                             No            1
# 32364           770                            Yes            0
# 32377           759                             No            0
# 32378           784                             No            0
# 32419           765                            Yes            0
# 32449           751                             No            0
# 32544           772                             No            0
# 32568           764                             No            0
# 33723           756                            Yes            0
# 34166           760                            Yes            0
# 39296           768                             No            0
# 43613           753                             No            1
# 44050           754                             No            1
# 44658           767                             No            1
# 44705           751                             No            1

# %%
df[df['previous_loan_defaults_on_file']=='No'].groupby('loan_status').count()
# Out:
#              person_age  person_gender  person_education  person_income  \
# loan_status
# 0                 12129          12129             12129          12129
# 1                  9998           9998              9998           9998
#
#              person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# loan_status
# 0                     12129                  12129      12129        12129
# 1                      9998                   9998       9998         9998
#
#              loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# loan_status
# 0                    12129                12129                       12129
# 1                     9998                 9998                        9998
#
#              credit_score  previous_loan_defaults_on_file
# loan_status
# 0                   12129                           12129
# 1                    9998                            9998

# %%
df[df['previous_loan_defaults_on_file']=='Yes'].groupby('loan_status').count()
# Out:
#              person_age  person_gender  person_education  person_income  \
# loan_status
# 0                 22851          22851             22851          22851
#
#              person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# loan_status
# 0                     22851                  22851      22851        22851
#
#              loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# loan_status
# 0                    22851                22851                       22851
#
#              credit_score  previous_loan_defaults_on_file
# loan_status
# 0                   22851                           22851

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %%
# Applying transformation on the numerical data on a temp data set, plotting results and then comparing with original

# %%
# loan_amnt
# cb_person_cred_hist_length
# loan_int_rate

# %%
temp = df.copy()
temp['person_age_log'] = np.log(df['person_age'])

temp['person_age_yeo'] = pt.fit_transform(temp['person_age'].values.reshape(-1,1)).flatten()


temp['loan_amnt_yeo'] = pt.fit_transform(temp['loan_amnt'].values.reshape(-1,1)).flatten()
temp['cb_person_cred_hist_length_yeo'] = pt.fit_transform(temp['cb_person_cred_hist_length'].values.reshape(-1,1)).flatten()
temp['cb_person_cred_hist_length_log'] = np.log(df['cb_person_cred_hist_length'])
temp['loan_int_rate_yeo'] = pt.fit_transform(temp['loan_int_rate'].values.reshape(-1,1)).flatten()

# %%
fig , axes = plt.subplots(4,2,figsize = (15,15))
sns.kdeplot(data = temp, x='person_age',ax=axes[0][0])
sns.kdeplot(data = temp, x='person_age_yeo',ax=axes[0][1])


sns.kdeplot(data = temp, x='loan_amnt',ax=axes[1][0])
sns.kdeplot(data = temp, x='loan_amnt_yeo',ax=axes[1][1])


sns.kdeplot(data = temp, x='cb_person_cred_hist_length',ax=axes[2][0])
sns.kdeplot(data = temp, x='cb_person_cred_hist_length_yeo',ax=axes[2][1])


sns.kdeplot(data = temp, x='loan_int_rate',ax=axes[3][0])
sns.kdeplot(data = temp, x='loan_int_rate_yeo',ax=axes[3][1])
# Out:
# <Axes: xlabel='loan_int_rate_yeo', ylabel='Density'>

# %%
temp.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status  person_age_log  person_age_yeo  \
# 0                             No            1        3.091042       -1.423559
# 1                            Yes            0        3.044522       -1.906467
# 2                             No            1        3.218876       -0.337822
# 3                             No            1        3.135494       -1.008635
# 4                             No            1        3.178054       -0.649860
#
#    loan_amnt_yeo  cb_person_cred_hist_length_yeo  \
# 0       2.534264                       -0.801284
# 1      -2.401473                       -1.554018
# 2      -0.535909                       -0.801284
# 3       2.534264                       -1.554018
# 4       2.534264                       -0.280342
#
#    cb_person_cred_hist_length_log  loan_int_rate_yeo
# 0                        1.098612           1.597168
# 1                        0.693147           0.100171
# 2                        1.098612           0.657078
# 3                        0.693147           1.369222
# 4                        1.386294           1.085484

# %%
# temp[temp['cb_person_cred_hist_length']>17][temp[temp['cb_person_cred_hist_length']>17]['loan_status']==0]

# %%
## appyling svm, logistic regression on initial data and get the accuracy once.
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
X = df[['person_age','person_income','person_emp_exp','loan_amnt','loan_int_rate','loan_percent_income','cb_person_cred_hist_length','credit_score']]
y=df['loan_status']

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=41)

# %%
svc = SVC(kernel='rbf')
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
print('accuracy for lr', accuracy_score(y_test, lr.predict(X_test)))
# Out:
# accuracy for lr 0.8267007558915074

# %%
svc.fit(X_train, y_train)
print('accuracy for SVC', accuracy_score(y_test, svc.predict(X_test)))
# Out:
# accuracy for SVC 0.8101378390395731

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 1                   0                   OWN     1000.0          EDUCATION
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [44978 rows x 14 columns]

# %%
temp = df.copy()
temp.to_csv('latest1.csv')

# %% [markdown]
# # Actions
# 1. Transformer on cage and loan amount
# 2. drop the outlier from majority class
# 3. then apply smote to get minority class up

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=41)

# %%
power = PowerTransformer(method='yeo-johnson')

# %%
col = ['person_age','loan_amnt']

# %%
trf = ColumnTransformer(transformers=[
    ('yeo',PowerTransformer(method='yeo-johnson'),col)
],remainder='drop')

# %%
X_transformed = trf.fit_transform(X_train)
X_test_trans = trf.fit(X_test)

# %%
cols =  X_train.columns

# %%
cols
# Out:
# Index(['person_age', 'person_income', 'person_emp_exp', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score'],
#       dtype='object')

# %%
X_transformed
# Out:
# array([[-1.42082343, -0.88381019],
#        [-1.00479655, -0.66202563],
#        [-0.6452353 ,  0.59912245],
#        ...,
#        [ 0.8962996 , -0.71476646],
#        [-0.6452353 ,  1.3247469 ],
#        [-0.6452353 ,  1.46341813]])

# %%
X_transformed = pd.DataFrame(X_transformed,columns=cols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[418], line 1
# ----> 1 X_transformed = pd.DataFrame(X_transformed,columns=cols)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (35982, 2), indices imply (35982, 8)

# %%
X_train
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 7112         22.0        63003.0               4     4200.0          10.59
# 11403        23.0        90346.0               1     5000.0          11.01
# 12424        24.0        52338.0               3    12000.0          11.36
# 6554         26.0        53721.0               2    10000.0           5.42
# 16776        25.0        49059.0               5     6500.0          11.89
# ...           ...            ...             ...        ...            ...
# 31601        36.0        54054.0              14     2000.0          13.61
# 41303        26.0        95601.0               0     9000.0           6.76
# 20454        31.0        27284.0              11     4800.0          10.65
# 935          24.0        94624.0               1    18500.0          15.33
# 34772        24.0       106097.0               2    20000.0          13.25
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score
# 7112                  0.07                         3.0           660
# 11403                 0.06                         3.0           693
# 12424                 0.23                         2.0           609
# 6554                  0.19                         4.0           582
# 16776                 0.13                         3.0           653
# ...                    ...                         ...           ...
# 31601                 0.04                        13.0           662
# 41303                 0.09                         6.0           658
# 20454                 0.18                        10.0           692
# 935                   0.20                         2.0           692
# 34772                 0.19                         5.0           585
#
# [35982 rows x 8 columns]

# %%
X_transformed
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0       -1.420823      -0.883810         63003.0        4.0          10.59
# 1       -1.004797      -0.662026         90346.0        1.0          11.01
# 2       -0.645235       0.599122         52338.0        3.0          11.36
# 3       -0.059447       0.314792         53721.0        2.0           5.42
# 4       -0.332655      -0.310775         49059.0        5.0          11.89
# ...           ...            ...             ...        ...            ...
# 35977    1.446192      -1.732688         54054.0       14.0          13.61
# 35978   -0.059447       0.155923         95601.0        0.0           6.76
# 35979    0.896300      -0.714766         27284.0       11.0          10.65
# 35980   -0.645235       1.324747         94624.0        1.0          15.33
# 35981   -0.645235       1.463418        106097.0        2.0          13.25
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score
# 0                     0.07                         3.0         660.0
# 1                     0.06                         3.0         693.0
# 2                     0.23                         2.0         609.0
# 3                     0.19                         4.0         582.0
# 4                     0.13                         3.0         653.0
# ...                    ...                         ...           ...
# 35977                 0.04                        13.0         662.0
# 35978                 0.09                         6.0         658.0
# 35979                 0.18                        10.0         692.0
# 35980                 0.20                         2.0         692.0
# 35981                 0.19                         5.0         585.0
#
# [35982 rows x 8 columns]

# %% [markdown]
# ### categorical columns analysis
# 1. person_gender
# 2. person_education
# 3. person_home_ownership
# 4. loan_intent
# 5. previous_loan_defaults_on_file

# %%
fig, axes = plt.subplots(2,3,figsize = (15,20))
sns.countplot(data = df, x='person_gender',ax = axes[0,0],palette='winter',hue='loan_status')
sns.countplot(data = df, x='person_education',ax = axes[0,1],palette='winter',hue='loan_status')
sns.countplot(data = df, x='person_home_ownership',ax = axes[0,2],palette='winter',hue='loan_status')
sns.countplot(data = df, x='loan_intent',ax = axes[1,0],palette='spring',hue='loan_status')
sns.countplot(data = df, x='previous_loan_defaults_on_file',ax = axes[1,1],palette='summer',hue='loan_status')
# Out:
# <Axes: xlabel='previous_loan_defaults_on_file', ylabel='count'>

# %% [markdown]
# # Insights for categorical columns
# 1. Which feature are governing that the loan will be approved or rejected
#    - Mortgage/rent rejection ration is very high
#    - calculate percentages amount of who's getting and who's not
